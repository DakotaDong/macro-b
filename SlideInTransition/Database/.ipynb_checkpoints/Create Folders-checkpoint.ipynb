# %%
import pandas as pd

# %%
family_df = pd.read_csv('family_export.csv',sep = ',', header=0)
order_df = pd.read_csv('order_export.csv',sep = ',', header=0)

# %%
family_df.head()
# Out:
#    id  orderId                 commonName scientificName  pollution  \
# 0   1        1    Long-toed Water Beetles      Dryopidae        NaN
# 1   2        1  Predacious Diving Beetles     Dytiscidae        NaN
# 2   3        1             Riffle Beetles        Elmidae        NaN
# 3   4        1          Whirligig Beetles      Gyrinidae        NaN
# 4   5        1     Crawling Water Beetles     Haliplidae        NaN
#
#                                          description
# 0  This family is relatively small, with only 5 N...
# 1  This is the largest North American family of a...
# 2  This is a large family, including 24 genera an...
# 3  Adult members of the family Gyrinidae are uniq...
# 4  This family includes over 70 North American sp...

# %%
order_df.head()
# Out:
#    id  commonName     scientificName   featuredImage  \
# 0   1     Beetles   Adult Coleoptera   adult-beetles
# 1   2     Beetles  Larvae Coleoptera  larval-beetles
# 2   3  True Flies            Diptera      true-flies
# 3   4    Mayflies      Ephemeroptera        mayfiles
# 4   5   True Bugs          Hemiptera        true-bug
#
#                               pollution  \
# 0                             Sensitive
# 1                             Sensitive
# 2  Sensitive; Less Sensitive; Tolerant.
# 3                             Sensitive
# 4                                   NaN
#
#                                           orderIntro  \
# 0  Three-pairs of legs; body usually covered by a...
# 1  Three-pairs of legs; body usually covered by a...
# 2  Usually the body is segmented with some type o...
# 3  Three-pairs of legs with a single hook at the ...
# 4   Both adults and larvae can be aquatic and occ...
#
#                                          lifeHistory  \
# ...

# %%
order_df.join(family_df.set_index('id'), on='id')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-dd29c32672e4> in <module>()
# ----> 1 order_df.join(family_df.set_index('orderId'), on='id')
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    7207         """
#    7208         return self._join_compat(
# -> 7209             other, on=on, how=how, lsuffix=lsuffix, rsuffix=rsuffix, sort=sort
#    7210         )
#    7211
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    7230                 right_index=True,
#    7231                 suffixes=(lsuffix, rsuffix),
# -> 7232                 sort=sort,
#    7233             )
#    7234         else:
#
# ...
